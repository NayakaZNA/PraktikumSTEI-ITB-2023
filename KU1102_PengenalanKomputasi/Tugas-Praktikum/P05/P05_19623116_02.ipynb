# %% [markdown]
# ## **Praktikum 05**
# ### *Problem 2*
# #### Praktikum Pengenalan Komputasi: Stream Programming
# - NIM/Nama  : 19623116/Zulfaqqar Nayaka Athadiansyah
# - Tanggal   : 16 November 2023
# - Deskripsi : Jupyter Notebook untuk Problem 2

# %%
#include <'pandas.h'>
import pandas as pd

# Import data .csv
df = pd.read_csv("P05-03.csv")

# Kamus
# df    : Dataframe

# %% [markdown]
# 1. Ada berapa data dengan jumlah malam penyewaan minimumnya 1 namun banyaknya review di aplikasi selama 12 bulan tidak 1?

# %%
print(f"Ada {len(df[(df['minimum_nights'] == 1) & (df['number_of_reviews'] != 1)])} data yang memenuhi kriteria tersebut.")
# Out:
# Ada 1841 data yang memenuhi kriteria tersebut.

# %% [markdown]
# 2. Siapa nama pemilik rumah dengan banyaknya hari ketersediaan rumah dalam satu tahunnya terbanyak?

# %%
df[df["availability_365"] == df["availability_365"][df["availability_365"].idxmax()]]
# Out:
#             id                                               name    host_id  \
# 0        49091                  COZICOMFORT LONG TERM STAY ROOM 2     266763
# 1        50646                    Pleasant Room along Bukit Timah     227796
# 2        56334                                        COZICOMFORT     266763
# 23      481789                 Master Bedroom in Newly Built Flat    2386154
# 26      642660                 BEST CITY LIVING WITH GA RESIDENCE    3212572
# ...        ...                                                ...        ...
# 7866  38027609                                可夫妻欢迎高尚工作人士,歌星,学生入住  287174284
# 7869  38029461     11 reason to stay- studio house in farrer park   32184450
# 7896  38088317                      V Close-to-CBD En-Suite Room2    8200399
# 7903  38108273                         3bedroom luxury at Orchard  238891646
# 7906  38112762  Amazing room with private bathroom walk to Orc...   28788520
#
# ...

# %%
# Alternatif (tampilkan nama saja)
df["host_name"][df["availability_365"] == df["availability_365"][df["availability_365"].idxmax()]]
# Out:
# 0       Francesca
# 1         Sujatha
# 2       Francesca
# 23          Susan
# 26          Roger
#           ...
# 7866           无殇
# 7869       Apollo
# 7896           V/
# 7903         Neha
# 7906      Terence
# Name: host_name, Length: 843, dtype: object

# %% [markdown]
# 3. Ada berapa rumah di daerah (neighbourhood group) Central Region atau East Region dengan harga rumah per malam di bawah 100?

# %%
print(f'Ada {len(df[(df["neighbourhood_group"] == "Central Region") | (df["neighbourhood_group"] == "East Region")])} rumah yang memenuhi kriteria tersebut.')
# Out:
# Ada 6817 rumah yang memenuhi kriteria tersebut.

# %% [markdown]
# 4. Banyaknya rumah dengan review per bulan di atas 1 untuk tiap jenis penyediaan ruang.

# %%
df["room_type"][df["reviews_per_month"] > 1].value_counts().to_frame()
# Out:
#                  count
# room_type
# Entire home/apt    873
# Private room       681
# Shared room         67

# %% [markdown]
# 5. 5 nama rumah berdasarkan banyaknya rumah yang disewakan oleh host terbanyak.

# %% [markdown]
# Pertama-tama dicari dahulu host penyedia rumah terbanyak.

# %%
df1 = df.sort_values("calculated_host_listings_count", ascending=[0])
df1
# Out:
#             id                                               name    host_id  \
# 3107  21151992  Cosy 2BR pent hse at Jurong/Clementi/Pasir Pan...   66406177
# 5950  32388996   CBD Spacious Apt. 2min walk to Tanjong Pagar MRT   66406177
# 5258  30004765       Stylish 1BR Located 7 mins from Tg Pagar MRT   66406177
# 5105  29522835        Minimalist, Comfortable 2BR in Central East   66406177
# 5104  29522642          Capacious  Homely 2BR APT in Orchard Area   66406177
# ...        ...                                                ...        ...
# 2903  20469489      MASTER Bedroom in Condo with Private bathroom  103483680
# 2902  20449193          Beautiful master bedroom near city center   24045610
# 5215  29870421                       Nearcity pod for the singles  224623818
# 6461  33782992  Charming 2-Bedroom Tiong Bahru Apt with Park View   17695743
# 1830  14927787                    Master bedroom in Charlton park   93851525
#
# ...

# %% [markdown]
# Jadi, host penyedia rumah terbanyak adalah Jay. Selanjutnya, cetak 5 nama rumah pertamanya:

# %%
# Cetak 5 nama rumah pertama
df1[df1["host_name"] == "Jay"][:5]
# Out:
#             id                                               name   host_id  \
# 3107  21151992  Cosy 2BR pent hse at Jurong/Clementi/Pasir Pan...  66406177
# 5950  32388996   CBD Spacious Apt. 2min walk to Tanjong Pagar MRT  66406177
# 5258  30004765       Stylish 1BR Located 7 mins from Tg Pagar MRT  66406177
# 5105  29522835        Minimalist, Comfortable 2BR in Central East  66406177
# 5104  29522642          Capacious  Homely 2BR APT in Orchard Area  66406177
#
#      host_name neighbourhood_group  neighbourhood  latitude  longitude  \
# 3107       Jay         West Region       Clementi   1.31639  103.75721
# 5950       Jay      Central Region  Downtown Core   1.27594  103.84512
# 5258       Jay      Central Region  Downtown Core   1.27439  103.84458
# 5105       Jay      Central Region        Geylang   1.31874  103.88261
# 5104       Jay      Central Region         Newton   1.30846  103.82857
#
#             room_type  price  minimum_nights  number_of_reviews last_review  \
# ...
